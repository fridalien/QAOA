# %% [markdown]
# ## Comparison of QAOA with bitflips in quantum circuit
# In this notebook the standard QAOA is compared to QAOA with a bitflip layer at each depth for a max cut problem.

# %%
from qaoa import QAOA, problems, mixers, initialstates

# %%
import numpy as np
import networkx as nx
import sys

sys.path.append("../")
from plotroutines import *

# %%
G = nx.read_gml("data/w_ba_n21_k4_0.gml")
nx.draw_networkx(G)
mincost=-25.23404480588015  # precalculated

# %% [markdown]
# Create QAOA instances, whereas the first instance is initialized with `flip=True`, and the last is initialized with `flip=False`

# %%
qaoa_flip = QAOA(
    initialstate=initialstates.Plus(),
    problem=problems.MaxCut(G=G),
    mixer=mixers.X(),
    flip=True,
)
qaoa = QAOA(
    initialstate=initialstates.Plus(),
    problem=problems.MaxCut(G=G),
    mixer=mixers.X(),
)

# %% [markdown]
# Run optimization until given max depth

# %%
maxdepth = 10
qaoa_flip.optimize(depth=maxdepth)
qaoa.optimize(depth=maxdepth)
# Out:
# 2024-06-26 09:52:52 [info     ] Calculating energy landscape for depth p=1... file=qaoa.qaoa func=sample_cost_landscape
# 1 0
# 2024-06-26 09:52:52 [info     ] Executing sample_cost_landscape file=qaoa.qaoa func=sample_cost_landscape
# 2024-06-26 09:52:52 [info     ] parameters: 2                  file=qaoa.qaoa func=sample_cost_landscape
# 2024-06-26 09:52:52 [info     ] Done execute                   file=qaoa.qaoa func=sample_cost_landscape

# %% [markdown]
# Plot approximation ratio

# %%
fig = pl.figure()
plot_ApproximationRatio(
    qaoa,
    maxdepth,
    mincost=-25.23404480588015,
    maxcost=0,
    label="QAOA vanilla",
    style="o--b",
    fig=fig,
)
plot_ApproximationRatio(
    qaoa_flip,
    maxdepth,
    mincost=-25.23404480588015,
    maxcost=0,
    label="QAOA flip",
    style="x--k",
    fig=fig,
)
